# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('wifi.csv', sep=';', parse_dates=True)
data1=data[(data['Zona']=='OWM Zona1') & (data['Data']>='2020-02-24 00:00:00+02:00')]

# %%
plt.plot(data1['Valore'])
