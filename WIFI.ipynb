# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('wifi.csv', sep=';', parse_dates=True)
data1=data[data['Data']>='2020-02-24 00:00:00+02:00']
data1=data1.groupby(['Data']).sum()
data1
# Out:
#                            Valore
# Data
# 2020-02-25 00:00:00+01:00    4652
# 2020-02-26 00:00:00+01:00    4456
# 2020-02-27 00:00:00+01:00    4576
# 2020-02-28 00:00:00+01:00    4783
# 2020-02-29 00:00:00+01:00    4046
# 2020-03-01 00:00:00+01:00    3381
# 2020-03-02 00:00:00+01:00    3469
# 2020-03-03 00:00:00+01:00    4872
# 2020-03-04 00:00:00+01:00    4966
# 2020-03-05 00:00:00+01:00    4288
# 2020-03-06 00:00:00+01:00    4820
# 2020-03-07 00:00:00+01:00    4555
# 2020-03-08 00:00:00+01:00    3714
# 2020-03-09 00:00:00+01:00    3662
# 2020-03-10 00:00:00+01:00    3317
# 2020-03-11 00:00:00+01:00    3177
# 2020-03-12 00:00:00+01:00    2462
# 2020-03-13 00:00:00+01:00    2439
# 2020-03-14 00:00:00+01:00    1840
# 2020-03-15 00:00:00+01:00    1665
# 2020-03-16 00:00:00+01:00    2261
# 2020-03-17 00:00:00+01:00    2233
# 2020-03-18 00:00:00+01:00    2086
# 2020-03-19 00:00:00+01:00    2026
# 2020-03-20 00:00:00+01:00    1979
# 2020-03-21 00:00:00+01:00    1665
# ...

# %%
plt.plot(data1['Valore'])
